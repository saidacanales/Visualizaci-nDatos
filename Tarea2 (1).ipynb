# %% [markdown]
# # Age Datasets

# %%
# %ls datasets/
# Out:
# adult.csv                  census.csv     movies.csv
# airline_data.csv           coches.csv     nhanes_2015_2016.csv
# antropometria00.csv        cwurData.csv   pokemon.csv
# antropometria-dataset.csv  data.csv       reg_data.csv
# Book3.csv                  headbrain.csv  sample_pivot.csv
# Canada.xlsx                mic2.xlsx      tips.csv
# Cartwheeldata.csv          mic.xlsx       weight-height.csv

# %%
import pandas as pd
import numpy as np

# %%
df22 = pd.read_csv('datasets/adult.csv')
df22
# Out:
#        age          workclass  fnlwgt   education  education-num  \
# 0       39          State-gov   77516   Bachelors             13
# 1       50   Self-emp-not-inc   83311   Bachelors             13
# 2       38            Private  215646     HS-grad              9
# 3       53            Private  234721        11th              7
# 4       28            Private  338409   Bachelors             13
# ...    ...                ...     ...         ...            ...
# 32559   22            Private  201490     HS-grad              9
# 32560   52       Self-emp-inc  287927     HS-grad              9
# 32561   52       Self-emp-inc  287927     HS-grad              9
# 32562   52       Self-emp-inc  287927     HS-grad              9
# 32563   52       Self-emp-inc  287927     HS-grad              9
#
#               marital-status          occupation    relationship    race  \
# 0              Never-married        Adm-clerical   Not-in-family   White
# ...

# %%
myPivot = pd.pivot_table(df,
                         aggfunc = ['count'],
                         index = ['marital-status'],
                         margins = True,
                         columns = ['marital-status'],
                        )
myPivot
# Out:
#                            count                                         \
#                              age
# marital-status          Divorced  Married-AF-spouse  Married-civ-spouse
# marital-status
#  Divorced                 4443.0                NaN                 NaN
#  Married-AF-spouse           NaN               23.0                 NaN
#  Married-civ-spouse          NaN                NaN             14976.0
#  Married-spouse-absent       NaN                NaN                 NaN
#  Never-married               NaN                NaN                 NaN
#  Separated                   NaN                NaN                 NaN
#  Widowed                     NaN                NaN                 NaN
#  test_category_female        NaN                NaN                 NaN
#  test_category_male          NaN                NaN                 NaN
# All                       4443.0               23.0             14976.0
#
# ...

# %%
myPivot.columns
# Out:
# MultiIndex([('count',       'age',              ' Divorced'),
#             ('count',       'age',     ' Married-AF-spouse'),
#             ('count',       'age',    ' Married-civ-spouse'),
#             ('count',       'age', ' Married-spouse-absent'),
#             ('count',       'age',         ' Never-married'),
#             ('count',       'age',             ' Separated'),
#             ('count',       'age',               ' Widowed'),
#             ('count',       'age',  ' test_category_female'),
#             ('count',       'age',    ' test_category_male'),
#             ('count',       'age',                    'All'),
#             ...
#             ('count', 'workclass',              ' Divorced'),
#             ('count', 'workclass',     ' Married-AF-spouse'),
#             ('count', 'workclass',    ' Married-civ-spouse'),
#             ('count', 'workclass', ' Married-spouse-absent'),
#             ('count', 'workclass',         ' Never-married'),
# ...

# %%
myPivot['Percentage'] = (myPivot[ ('count', 'workclass',                    'All')]/32564)*100
myPivot
# Out:
#                            count                                         \
#                              age
# marital-status          Divorced  Married-AF-spouse  Married-civ-spouse
# marital-status
#  Divorced                 4443.0                NaN                 NaN
#  Married-AF-spouse           NaN               23.0                 NaN
#  Married-civ-spouse          NaN                NaN             14976.0
#  Married-spouse-absent       NaN                NaN                 NaN
#  Never-married               NaN                NaN                 NaN
#  Separated                   NaN                NaN                 NaN
#  Widowed                     NaN                NaN                 NaN
#  test_category_female        NaN                NaN                 NaN
#  test_category_male          NaN                NaN                 NaN
# All                       4443.0               23.0             14976.0
#
# ...

# %%
c1 = (df22['marital-status']== 'Married-civ-spouse')
c2 = (df22['marital-status']== 'Married-spouse-absent')
c3 = (df22['marital-status']== 'Married-AF-spouse')
newdf = df22[c1]
newdf
# Out:
# Empty DataFrame
# Columns: [age, workclass, fnlwgt, education, education-num, marital-status, occupation, relationship, race, sex, capital-gain, capital-loss, hours-per-week, native-country, the label]
# Index: []
